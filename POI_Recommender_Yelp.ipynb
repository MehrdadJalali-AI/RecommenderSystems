# %% [markdown]
# <a href="https://colab.research.google.com/github/MehrdadJalali-AI/RecommenderSystems/blob/main/POI_Recommender_Yelp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="background-color:#ffffff; border:3px solid #f15a22; border-radius:10px; padding:25px; text-align:center; font-family:'Segoe UI',sans-serif;">
#   <h1 style="color:#003366;">Point-of-Interest (POI) Recommender System</h1>
#   <h2 style="color:#f15a22;">Yelp Dataset · Collaborative Filtering · Geolocation</h2>
#   <p style="color:#003366;"><strong>Author:</strong> Prof. Mehrdad Jalali | SRH University Heidelberg</p>
#   <p style="font-style:italic; color:#444;">An interactive and visually engaging tutorial for building location-aware recommender systems.</p>
# </div>

# %% [markdown]
# ## 🎯 Learning Objectives
#
# By completing this notebook, you will:
# 1. **Load and explore** real Yelp review data
# 2. **Build a user–item matrix** for collaborative filtering
# 3. **Compute cosine similarity** between businesses
# 4. **Predict missing ratings** using item-item CF
# 5. **Integrate geolocation** for distance-aware recommendations
# 6. **Generate personalized POIs** ranked by proximity and preference
# 7. **Visualize results** interactively on a map
#
# ---
#
# ## 🧭 Notebook Roadmap
#
# | Step | Goal |
# |------|------|
# | 1 | Setup & import libraries |
# | 2 | Load & explore data |
# | 3 | Build rating matrix |
# | 4 | Compute item similarity |
# | 5 | Predict ratings |
# | 6 | Add distance weighting |
# | 7 | Generate recommendations |
# | 8 | Visualize results |
# | 9 | Summary & reflections |

# %% [markdown]
# ## Step 1️⃣ — Setup & Import Libraries
#
# We use the following:
# - **pandas** / **numpy** for data manipulation
# - **cosine_similarity** from `sklearn` for CF
# - **geopy** for geographic distance
# - **folium** for map visualization
#
# Let's load them and confirm success.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from geopy.distance import geodesic
import folium
from IPython.display import IFrame, display
import warnings
warnings.filterwarnings("ignore")

print("✅ All libraries imported successfully.")
# Out:
# ✅ All libraries imported successfully.

# %% [markdown]
# ## Step 2️⃣ — Load and Explore the Yelp Dataset
#
# We use a **sample** from the Yelp dataset hosted in your course repository.
# This includes:
# - User IDs
# - Business IDs
# - Ratings (`stars`)
# - Geographic coordinates
# - Categories

# %%
url = "https://raw.githubusercontent.com/MehrdadJalali-AI/RecommenderSystems/main/YelpDataset/yelp_sample.csv"
yelp = pd.read_csv(url)
print(f"✅ Yelp dataset loaded successfully! Shape: {yelp.shape}")
display(yelp.head())
# Out:
# ✅ Yelp dataset loaded successfully! Shape: (5000, 6)
#                   user_id             business_id  stars   latitude  \
# 0  JJ-qgqyl4M3N88owKJRJHw  H3JjbID9Zhukpqr9uupHAA      4  36.136630
# 1  6j4NN66UESCtdcNJulB4fw  _Xo-JzgxbMaDi5cvlfHpwg      1  27.994221
# 2  nE90dt6_P6UyFe80LUrnvQ  WbA5ud4InNWkizW7HE5kRQ      1  32.220970
# 3  kaHmTcEoVS3oQvfJfDe8kg  KhBUg5QhBYuK8RZAe5gDMQ      5  27.991950
# 4  SIhJRPMoUxspakLdm6NS_w  GBTPC53ZrG1ZBY3DT8Mbcw      5  29.950742
#
#     longitude                                         categories
# 0  -86.800437  Burgers, Bars, Restaurants, Nightlife, America...
# 1  -82.220255                              Restaurants, Barbeque
# 2 -110.970157  Mexican, Restaurants, Nightlife, Bars, Venues ...
# 3  -82.459645  Restaurants, Nightlife, Pubs, Food, Bars, Amer...
# 4  -90.070416  German, Restaurants, Seafood, Cocktail Bars, F...

# %% [markdown]
# ## Step 3️⃣ — Build the User–Item Rating Matrix
#
# Each **row** represents a user, each **column** represents a business,
# and each cell stores a rating. Missing values are replaced with 0.

# %%
ratings = yelp.pivot_table(values='stars', index='user_id', columns='business_id', fill_value=0)
print(f"Matrix created → Users: {ratings.shape[0]}, Businesses: {ratings.shape[1]}")
display(ratings.iloc[:5, :5].style.background_gradient(cmap='Blues'))
# Out:
# Matrix created → Users: 4906, Businesses: 2034
# <style type="text/css">
# #T_9a93c_row0_col0, #T_9a93c_row0_col1, #T_9a93c_row0_col2, #T_9a93c_row0_col3, #T_9a93c_row0_col4, #T_9a93c_row1_col0, #T_9a93c_row1_col1, #T_9a93c_row1_col2, #T_9a93c_row1_col3, #T_9a93c_row1_col4, #T_9a93c_row2_col0, #T_9a93c_row2_col1, #T_9a93c_row2_col2, #T_9a93c_row2_col3, #T_9a93c_row2_col4, #T_9a93c_row3_col0, #T_9a93c_row3_col1, #T_9a93c_row3_col2, #T_9a93c_row3_col3, #T_9a93c_row3_col4, #T_9a93c_row4_col0, #T_9a93c_row4_col1, #T_9a93c_row4_col2, #T_9a93c_row4_col3, #T_9a93c_row4_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_9a93c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >business_id</th>
#       <th id="T_9a93c_level0_col0" class="col_heading level0 col0" >-1MhPXk1FglglUAmuPLIGg</th>
#       <th id="T_9a93c_level0_col1" class="col_heading level0 col1" >-2Axhv9AZ_n7qjQefECpVw</th>
#       <th id="T_9a93c_level0_col2" class="col_heading level0 col2" >-3AooxIkg38UyUdlz5oXdw</th>
#       <th id="T_9a93c_level0_col3" class="col_heading level0 col3" >-7GDqSUaXrpC8Ql7nDBxWA</th>
#       <th id="T_9a93c_level0_col4" class="col_heading level0 col4" >-ATiAtTikuGuqvaW2O6tNA</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >user_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a93c_level0_row0" class="row_heading level0 row0" >--2bpE5vyR-2hAP7sZZ4lA</th>
#       <td id="T_9a93c_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_9a93c_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_9a93c_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_9a93c_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_9a93c_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9a93c_level0_row1" class="row_heading level0 row1" >--t1GgwabT-J_6OQG8f5QQ</th>
#       <td id="T_9a93c_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_9a93c_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_9a93c_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_9a93c_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_9a93c_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9a93c_level0_row2" class="row_heading level0 row2" >--u09WAjW741FdfkJXxNmg</th>
#       <td id="T_9a93c_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_9a93c_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_9a93c_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_9a93c_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_9a93c_row2_col4" class="data row2 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9a93c_level0_row3" class="row_heading level0 row3" >-0Ath8bD1-e01-oMSPw9ig</th>
#       <td id="T_9a93c_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_9a93c_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_9a93c_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_9a93c_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_9a93c_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9a93c_level0_row4" class="row_heading level0 row4" >-0EcgtUXe1rzrkmdih_tYg</th>
#       <td id="T_9a93c_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_9a93c_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_9a93c_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_9a93c_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_9a93c_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 4️⃣ — Compute Item–Item Similarity
#
# We use **cosine similarity** to measure how similar two businesses are
# based on how users rated them.

# %%
print("⏳ Computing cosine similarity between items...")
item_similarity = cosine_similarity(ratings.T)
item_similarity_df = pd.DataFrame(item_similarity, index=ratings.columns, columns=ratings.columns)
print("✅ Item–Item similarity matrix ready.")
display(item_similarity_df.iloc[:5, :5].style.background_gradient(cmap='coolwarm'))
# Out:
# ⏳ Computing cosine similarity between items...
# ✅ Item–Item similarity matrix ready.
# <style type="text/css">
# #T_0ff4a_row0_col0, #T_0ff4a_row1_col1, #T_0ff4a_row2_col2, #T_0ff4a_row3_col3, #T_0ff4a_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0ff4a_row0_col1, #T_0ff4a_row0_col2, #T_0ff4a_row0_col3, #T_0ff4a_row0_col4, #T_0ff4a_row1_col0, #T_0ff4a_row1_col2, #T_0ff4a_row1_col3, #T_0ff4a_row1_col4, #T_0ff4a_row2_col0, #T_0ff4a_row2_col1, #T_0ff4a_row2_col3, #T_0ff4a_row2_col4, #T_0ff4a_row3_col0, #T_0ff4a_row3_col1, #T_0ff4a_row3_col2, #T_0ff4a_row3_col4, #T_0ff4a_row4_col0, #T_0ff4a_row4_col1, #T_0ff4a_row4_col2, #T_0ff4a_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0ff4a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >business_id</th>
#       <th id="T_0ff4a_level0_col0" class="col_heading level0 col0" >-1MhPXk1FglglUAmuPLIGg</th>
#       <th id="T_0ff4a_level0_col1" class="col_heading level0 col1" >-2Axhv9AZ_n7qjQefECpVw</th>
#       <th id="T_0ff4a_level0_col2" class="col_heading level0 col2" >-3AooxIkg38UyUdlz5oXdw</th>
#       <th id="T_0ff4a_level0_col3" class="col_heading level0 col3" >-7GDqSUaXrpC8Ql7nDBxWA</th>
#       <th id="T_0ff4a_level0_col4" class="col_heading level0 col4" >-ATiAtTikuGuqvaW2O6tNA</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >business_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ff4a_level0_row0" class="row_heading level0 row0" >-1MhPXk1FglglUAmuPLIGg</th>
#       <td id="T_0ff4a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0ff4a_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_0ff4a_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_0ff4a_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_0ff4a_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0ff4a_level0_row1" class="row_heading level0 row1" >-2Axhv9AZ_n7qjQefECpVw</th>
#       <td id="T_0ff4a_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_0ff4a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0ff4a_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_0ff4a_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_0ff4a_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0ff4a_level0_row2" class="row_heading level0 row2" >-3AooxIkg38UyUdlz5oXdw</th>
#       <td id="T_0ff4a_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_0ff4a_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_0ff4a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0ff4a_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_0ff4a_row2_col4" class="data row2 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0ff4a_level0_row3" class="row_heading level0 row3" >-7GDqSUaXrpC8Ql7nDBxWA</th>
#       <td id="T_0ff4a_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_0ff4a_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_0ff4a_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_0ff4a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0ff4a_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0ff4a_level0_row4" class="row_heading level0 row4" >-ATiAtTikuGuqvaW2O6tNA</th>
#       <td id="T_0ff4a_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_0ff4a_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_0ff4a_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_0ff4a_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_0ff4a_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 5️⃣ — Predict Ratings (Item–Item CF)
#
# For each unrated business, we estimate a rating
# based on ratings of **similar items**.

# %%
def predict_ratings_for_user(user_id):
    user_ratings = ratings.loc[user_id]
    rated_items = user_ratings[user_ratings > 0].index.tolist()
    predictions = {}
    for item in ratings.columns:
        if item not in rated_items:
            sim_items = item_similarity_df[item][rated_items]
            sim_scores = sim_items * user_ratings[rated_items]
            pred = sim_scores.sum() / (sim_items.sum() + 1e-9)
            predictions[item] = pred
    return pd.Series(predictions).sort_values(ascending=False)
print("✅ Rating prediction function defined.")
# Out:
# ✅ Rating prediction function defined.

# %% [markdown]
# ## Step 6️⃣ — Add Geolocation Context
#
# We apply **distance-aware scoring**:
# Closer POIs get slightly higher priority using exponential decay weighting.

# %%
def recommend_poi(user_id, user_lat, user_lon, top_n=5, lambda_geo=0.02):
    preds = predict_ratings_for_user(user_id)
    recs = pd.DataFrame(preds, columns=['pred_rating']).reset_index()
    recs.rename(columns={'index': 'business_id'}, inplace=True)
    recs = recs.merge(yelp[['business_id','latitude','longitude','categories']].drop_duplicates(), on='business_id', how='left')
    recs['distance_km'] = recs.apply(lambda x: geodesic((user_lat, user_lon), (x.latitude, x.longitude)).km, axis=1)
    recs['final_score'] = recs['pred_rating'] * np.exp(-lambda_geo * recs['distance_km'])
    return recs.sort_values('final_score', ascending=False).head(top_n)
print("✅ Location-aware recommender function ready.")
# Out:
# ✅ Location-aware recommender function ready.

# %% [markdown]
# ## Step 7️⃣ — Generate Personalized Recommendations
#
# Let’s pick one user and generate top recommendations
# based on their preferences and proximity.

# %%
sample_user = yelp['user_id'].iloc[0]
sample_lat = yelp['latitude'].mean()
sample_lon = yelp['longitude'].mean()
recommendations = recommend_poi(sample_user, sample_lat, sample_lon, top_n=5)
print(f"📍 Top Recommendations for User {sample_user[:8]}:")
display(recommendations[['business_id','categories','pred_rating','distance_km','final_score']].style.background_gradient(cmap='Oranges'))
# Out:
# 📍 Top Recommendations for User JJ-qgqyl:
# <style type="text/css">
# #T_2adad_row0_col2, #T_2adad_row0_col3, #T_2adad_row0_col4, #T_2adad_row1_col2, #T_2adad_row1_col4, #T_2adad_row2_col2, #T_2adad_row2_col4, #T_2adad_row3_col2, #T_2adad_row3_col4, #T_2adad_row4_col2, #T_2adad_row4_col3, #T_2adad_row4_col4 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_2adad_row1_col3 {
#   background-color: #fdbe84;
#   color: #000000;
# }
# #T_2adad_row2_col3 {
#   background-color: #feecda;
#   color: #000000;
# }
# #T_2adad_row3_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2adad" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2adad_level0_col0" class="col_heading level0 col0" >business_id</th>
#       <th id="T_2adad_level0_col1" class="col_heading level0 col1" >categories</th>
#       <th id="T_2adad_level0_col2" class="col_heading level0 col2" >pred_rating</th>
#       <th id="T_2adad_level0_col3" class="col_heading level0 col3" >distance_km</th>
#       <th id="T_2adad_level0_col4" class="col_heading level0 col4" >final_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2adad_level0_row0" class="row_heading level0 row0" >2032</th>
#       <td id="T_2adad_row0_col0" class="data row0 col0" >-2Axhv9AZ_n7qjQefECpVw</td>
#       <td id="T_2adad_row0_col1" class="data row0 col1" >Greek, Mediterranean, Restaurants, American (Traditional)</td>
#       <td id="T_2adad_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_2adad_row0_col3" class="data row0 col3" >158.665746</td>
#       <td id="T_2adad_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2adad_level0_row1" class="row_heading level0 row1" >2016</th>
#       <td id="T_2adad_row1_col0" class="data row1 col0" >zYu2D8FzczailDkEMURExg</td>
#       <td id="T_2adad_row1_col1" class="data row1 col1" >Sandwiches, Restaurants, Seafood, Steakhouses</td>
#       <td id="T_2adad_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_2adad_row1_col3" class="data row1 col3" >1015.722585</td>
#       <td id="T_2adad_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2adad_level0_row2" class="row_heading level0 row2" >2015</th>
#       <td id="T_2adad_row2_col0" class="data row2 col0" >zYy9lS8HlpbCHsGPmORTfA</td>
#       <td id="T_2adad_row2_col1" class="data row2 col1" >Bars, Pubs, Restaurants, Nightlife, Food, Breweries, Brewpubs, Burgers</td>
#       <td id="T_2adad_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_2adad_row2_col3" class="data row2 col3" >360.535401</td>
#       <td id="T_2adad_row2_col4" class="data row2 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2adad_level0_row3" class="row_heading level0 row3" >2014</th>
#       <td id="T_2adad_row3_col0" class="data row3 col0" >zbrIMldF_O1ZQ0vpUaaa8A</td>
#       <td id="T_2adad_row3_col1" class="data row3 col1" >Seafood, Venues & Event Spaces, Cocktail Bars, Restaurants, Nightlife, Breakfast & Brunch, American (Traditional), Event Planning & Services, Bars, American (New)</td>
#       <td id="T_2adad_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_2adad_row3_col3" class="data row3 col3" >2855.963034</td>
#       <td id="T_2adad_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2adad_level0_row4" class="row_heading level0 row4" >2013</th>
#       <td id="T_2adad_row4_col0" class="data row4 col0" >zbvu8pRKcOQqdjqRGbncyQ</td>
#       <td id="T_2adad_row4_col1" class="data row4 col1" >Southern, American (Traditional), American (New), Restaurants, Comfort Food</td>
#       <td id="T_2adad_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_2adad_row4_col3" class="data row4 col3" >162.235049</td>
#       <td id="T_2adad_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 🗺️ Step 8️⃣ — Interactive Map Visualization (Inline in Colab)
#
# Now that we have our personalized POI recommendations 🎯,
# let’s **visualize them directly on an interactive map** — right here in the notebook.
#
# ---
#
# ### 🌍 What This Map Shows
#
# | Marker | Meaning | Color |
# |---------|----------|--------|
# | 🔵 Circle | **User Location** | SRH Blue (`#003366`) |
# | 🟠 Circle | **Recommended Places** | SRH Orange (`#f15a22`) |
#
# Each recommendation is represented by a circle whose:
# - **Size** corresponds to its **final recommendation score**
# - **Popup window** shows:
#   - Category
#   - Predicted rating
#   - Distance from user (in km)
#   - Weighted final score
#
# ---
#
# ### 🧠 How It Works
# 1. The code uses **Folium** to create a map centered on the user’s location.
# 2. Recommended businesses are added with dynamically scaled circle markers.
# 3. You can **zoom**, **pan**, and **click markers** to see recommendation details.
# 4. The map is displayed **inline** (no external file or download required).
#
# > 💡 Tip: Try zooming in or panning the map — it’s fully interactive!

# %%
import folium

try:
    # 🧹 Clean data: remove missing coordinates or scores
    recommendations = recommendations.dropna(subset=['latitude', 'longitude', 'final_score'])
    if recommendations.empty:
        raise ValueError("No valid recommendations with coordinates to plot.")

    # Handle zero or NaN scores safely
    max_score = recommendations['final_score'].max()
    if max_score == 0 or np.isnan(max_score):
        max_score = 1e-5  # Prevent division by zero

    # 🗺️ Create map centered on the user
    m = folium.Map(location=[sample_lat, sample_lon], zoom_start=12, tiles='CartoDB positron')

    # 🔵 Add user marker (SRH Blue)
    folium.CircleMarker(
        location=[sample_lat, sample_lon],
        radius=8,
        color='#003366',
        fill=True,
        fill_color='#003366',
        popup=folium.Popup("<b>You are here</b>", max_width=200)
    ).add_to(m)

    # 🟠 Add recommended POIs (SRH Orange)
    for _, row in recommendations.iterrows():
        score = max(row['final_score'], 0)
        popup_html = f"""
        <div style='font-family:sans-serif; font-size:12px;'>
            <b style='color:#f15a22;'>Recommended Place</b><br>
            <b>Category:</b> {row['categories'][:80]}<br>
            <b>Predicted Rating:</b> {row['pred_rating']:.2f}<br>
            <b>Distance:</b> {row['distance_km']:.1f} km<br>
            <b>Score:</b> {score:.3f}
        </div>
        """
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=5 + 10 * score / max_score,   # Safe scaling
            color='#f15a22',
            fill=True,
            fill_opacity=0.85,
            fill_color='#f78b55',
            popup=folium.Popup(popup_html, max_width=300)
        ).add_to(m)

    # ✅ Display the map directly in Colab
    print("✅ Interactive map created successfully!")
    m

except Exception as e:
    print(f"⚠️ Map visualization skipped due to error: {e}")
# Out:
# ✅ Interactive map created successfully!

# %% [markdown]
# <div style="background-color:#f4f6f8; border-left:5px solid #f15a22; padding:20px; border-radius:8px;">
# <h2 style="color:#003366;">🧩 Step 9 — Summary & Reflection</h2>
# <p><strong>You built a full Point-of-Interest Recommender System!</strong></p>
# <ul>
#   <li>✅ Implemented Item–Item Collaborative Filtering</li>
#   <li>✅ Integrated geolocation context for distance-aware results</li>
#   <li>✅ Visualized recommendations interactively with Folium</li>
# </ul>
# <p><strong>Next Steps:</strong></p>
# <ul>
#   <li>📊 Add temporal context (time of day, recency)</li>
#   <li>🧠 Use deep learning (autoencoders or embeddings)</li>
#   <li>🗺️ Deploy as a web app using Streamlit</li>
# </ul>
# <p style="color:#003366; font-weight:bold;">SRH University Heidelberg · Applied Data Science</p>
# </div>
